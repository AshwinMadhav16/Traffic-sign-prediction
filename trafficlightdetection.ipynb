# %%
# !nvidia-smi
# Out:
# Mon Feb  3 09:10:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nzoXTYo4HAVFXLMB7R8V")
project = rf.workspace("my-jvrqh").project("traffic_sign-gv5rp-t0k2e-4y3sn")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic_Sign-2 in yolov8:: 100%|██████████| 3154/3154 [00:00<00:00, 7239.47it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Traffic_Sign-2/data.yaml epochs=25 imgsz=640 batch=8
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 98.6MB/s]
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt source=/content/Traffic_Sign-2/valid/images save=True
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 3,011,108 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/387 /content/Traffic_Sign-2/valid/images/BA-10-_jpg.rf.58af84065c9e310b8732833cb3edf2c5.jpg: 576x640 1 Barrier Ahead, 38.9ms
# image 2/387 /content/Traffic_Sign-2/valid/images/BA-11-_jpg.rf.bca68a89757e2518f5122f079075ac0d.jpg: 640x608 (no detections), 34.0ms
# image 3/387 /content/Traffic_Sign-2/valid/images/BA-11-_png.rf.b47153d5c58ce2c13e7e037d42fe2ecc.jpg: 640x640 1 Barrier Ahead, 8.2ms
# image 4/387 /content/Traffic_Sign-2/valid/images/BA-12-_jpg.rf.8f995c446acaea891ab0ba286a33dfeb.jpg: 640x640 1 Barrier Ahead, 7.4ms
# image 5/387 /content/Traffic_Sign-2/valid/images/BA-12-_png.rf.12ea20da4aa54a36d084f4defff16012.jpg: 640x640 1 Barrier Ahead, 7.4ms
# image 6/387 /content/Traffic_Sign-2/valid/images/BA-13-_png.rf.c9fde4965dfaac58582747cee12348df.jpg: 640x640 1 Barrier Ahead, 7.4ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/trafficsign.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip trafficsign.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: trafficsign.pt (deflated 9%)
#   adding: train/ (stored 0%)
#   adding: train/results.png (deflated 7%)
#   adding: train/confusion_matrix.png (deflated 16%)
#   adding: train/F1_curve.png (deflated 9%)
#   adding: train/val_batch0_pred.jpg (deflated 17%)
#   adding: train/train_batch1951.jpg (deflated 21%)
#   adding: train/train_batch1.jpg (deflated 15%)
#   adding: train/results.csv (deflated 60%)
#   adding: train/labels.jpg (deflated 23%)
#   adding: train/val_batch2_pred.jpg (deflated 9%)
#   adding: train/P_curve.png (deflated 10%)
#   adding: train/train_batch1950.jpg (deflated 19%)
#   adding: train/confusion_matrix_normalized.png (deflated 12%)
#   adding: train/train_batch0.jpg (deflated 7%)
#   adding: train/val_batch0_labels.jpg (deflated 17%)
#   adding: train/val_batch2_labels.jpg (deflated 9%)
#   adding: train/args.yaml (deflated 53%)
#   adding: train/val_batch1_pred.jpg (deflated 8%)
#   adding: train/PR_curve.png (deflated 13%)
# ...
